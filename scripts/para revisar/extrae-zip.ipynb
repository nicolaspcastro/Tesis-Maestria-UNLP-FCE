# %%
import zipfile as zf
import os as os

# %%
path1=r"C:\Users\nicoc\Google Drive\Facultad\Maestria\Tesis\Estimaciones\data\data_in\EPH\Bases Originales\EPH INDEC\Bases en Otros formatos\EPHP - 1991 - 2006\bases_por_año"

lista=os.listdir(path=path1)

lista = [l for l in lista if ".ini" not in l]

lista
# Out:
# ['1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006']

# %%
for año in lista:

    archivos = os.listdir(path=path1 + "\\" + str(año))
    archivos = [arch for arch in archivos if ".ini" not in arch]

    for archivo in archivos:

        name = archivo.split(".")[0]
        ruta_zip = path1 + "\\" + str(año) + "\\" + name + ".zip"
        ruta_extraccion = path1 + "\\" + str(año) + "\\" + name

        archivo_zip = zf.ZipFile(ruta_zip, "r")
        try:
            print(archivo_zip.namelist())
            archivo_zip.extractall(pwd=None, path=ruta_extraccion)
        except:
            pass
        archivo_zip.close()
# Out:
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ['BTHOG.DBF', 'BTPER.DBF', 'Registro_BT.doc']
# ...
